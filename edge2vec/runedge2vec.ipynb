# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/edge2vec
# Out:
# sample_data/

# %%
ls
# Out:
# 4/1AY0e-g7xWOIUDOO16SU3oH7wFZg1mNeXePnoZb_SvhUgsS7kQlGlGdU_Rt8sample_data/

# %%
# !python transition2.py --input subreddit.edgelist --output reddit_matrix.txt --type_size 2 --em_iteration 5 --e_step 3 --walk-length 3 --num-walks 2
# Out:
# begin to initialize transition matrix
#
# ------begin to read graph---------
# ddd
# subreddit.edgelist
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...

# %%
 # !python edge2vec2.py --input subreddit.edgelist --matrix reddit_matrix.txt --output reddit_embed300.txt --dimensions 300 --walk-length 3 --num-walks 2 --p 1 --q 1
# Out:
# begin to read transition matrix
# [[0.73105858 0.5       ]
#  [0.5        0.5       ]]
# ------begin to read graph---------
# ------begin to simulate walk---------
# Walk iteration:
# 1/2
# 2/2
